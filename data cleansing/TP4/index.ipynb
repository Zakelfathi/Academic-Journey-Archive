# %%
import pandas as pd
# import plotly.express as px
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_14852/1362513408.py in <module>
#       1 import pandas as pd
# ----> 2 import plotly.express as px
#
# ModuleNotFoundError: No module named 'plotly'

# %% [markdown]
# # DB : country_wise_latest.csv

# %% [markdown]
# ### Map : Confirmed, Deaths

# %%
df_country_wise_latest = pd.read_csv('./datasets/country_wise_latest.csv')
df_country_wise_latest
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      27532     546       7660   19326        658
# 1               Albania       1788      39       1086     663         66
# 2               Algeria      11385     811       8078    2496        117
# 3               Andorra        855      52        792      11          1
# 4                Angola        166       8         64      94         11
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza        600       3        415     182         45
# 183      Western Sahara          9       1          8       0          0
# 184               Yemen        909     248        273     388          7
# 185              Zambia       1416      11       1144     261          4
# 186            Zimbabwe        463       4         63     396         62
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
# !pip install plotly-express
# Out:
# ...
#      --                                       1.1/15.2 MB 4.3 kB/s eta 0:54:26
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\EliteBooK\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pip\_vendor\urllib3\response.py", line 438, in _error_catcher
#     yield
#   File "C:\Users\EliteBooK\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pip\_vendor\urllib3\response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "C:\Users\EliteBooK\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pip\_vendor\urllib3\response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
# ...

# %%
import plotly.express as px
# group the data by country/region and sum the deaths and confirmed cases
grouped_df = df_country_wise_latest.groupby(['Country/Region']).agg({'Deaths': 'sum', 'Confirmed': 'sum'}).reset_index()

# create the map using plotly express
fig = px.choropleth(grouped_df, locations='Country/Region', locationmode='country names', color='Deaths',
                    title='Deaths by Country/Region')
fig.show()

fig = px.choropleth(grouped_df, locations='Country/Region', locationmode='country names', color='Confirmed',
                    title='Confirmed Cases by Country/Region')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\ELITEB~1\AppData\Local\Temp/ipykernel_14852/2580122334.py in <module>
# ----> 1 import plotly.express as px
#       2 # group the data by country/region and sum the deaths and confirmed cases
#       3 grouped_df = df_country_wise_latest.groupby(['Country/Region']).agg({'Deaths': 'sum', 'Confirmed': 'sum'}).reset_index()
#       4
#       5 # create the map using plotly express
#
# ModuleNotFoundError: No module named 'plotly'
